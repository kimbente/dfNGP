# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from configs import N_SIDE
import configs

# attach this to paths since we are running from subfolder
subfolder_pre = "../"

list_of_regions = ["region_upper_byrd", "region_mid_byrd", "region_lower_byrd"]

# %% [markdown]
# # dfNGP

# %% [markdown]
# ## dfNGP Loss convergence

# %%
model_name = "dfNGP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    fig, ax1 = plt.subplots(figsize = (8, 5))

    # Primary y-axis: RMSE
    ax1.plot(losses["Epoch"], losses["Test RMSE"], label = "Test RMSE", color = "red")
    ax1.plot(losses["Epoch"], losses["Train RMSE"], label = "Train RMSE", color = "blue")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("RMSE Loss")
    ax1.tick_params(axis = 'y', labelcolor = "black")

    # Secondary y-axis: NLML
    ax2 = ax1.twinx()
    ax2.plot(losses["Epoch"], losses["Train NLML"], label = "Train Loss NLML", color = "green", linestyle = "--")
    ax2.plot(losses["Epoch"], losses["Test NLML"], label = "Test Loss NLML", color = "cyan", linestyle = "--")
    ax2.set_ylabel("Negative Log Marginal Likelihood (NLML) - objective", color = "green")
    ax2.tick_params(axis = 'y', labelcolor = "green")

    # Combine legends
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc = "upper right")

    plt.title(f"{region_name.upper()} {model_name} Training & Test Loss Over Epochs for Run 1")
    ax1.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## dfNGP hyperparameter evolution

# %%
model_name = "dfNGP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    plt.figure(figsize = (8, 5))
    plt.plot(losses["Epoch"], losses["l1"], label = "l1", color = "peru", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["l2"], label = "l2", color = "sienna", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["outputscale_var"], label = "Outputscale var.", color = "teal")
    plt.plot(losses["Epoch"], losses["noise_var"], label = "Noise var.", color = "teal")

    plt.xlabel("Epochs")
    plt.ylabel("GP hyperparameters")
    plt.title(f"{region_name.upper()} {model_name} Hyperparameter convergence for Run 1")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## dfNGP Predictions

# %%
model_name = "dfNGP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    ### Training data ###
    # Step 1: define paths based on region_name
    path_to_training_tensor = subfolder_pre + "data/real_data/" + region_name + "_train_tensor.pt"
    path_to_test_tensor = subfolder_pre + "data/real_data/" + region_name + "_test_tensor.pt"

    # Step 2: load and tranpose to have rows as points
    train = torch.load(path_to_training_tensor, weights_only = False).T 
    test = torch.load(path_to_test_tensor, weights_only = False).T

    # Step 3: Extract data
    # train
    x_train = train[:, [0, 1]].detach().cpu()
    y_train = train[:, [3, 4]].detach().cpu()

    # test
    x_test = test[:, [0, 1]].detach().cpu()
    y_test = test[:, [3, 4]].detach().cpu()

    ### Predictions ###
    path_predictions = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_test_mean_predictions.pt"
    
    # NOTE: pt
    y_test_predictions = torch.load(path_predictions, weights_only = False).detach().cpu().numpy()

    fig, axes = plt.subplots(1, 2, figsize = (10, 5))

    # --- Plot Ground Truth on the left ---
    axes[0].quiver(x_test[:, 0], x_test[:, 1], y_test[:, 0], y_test[:, 1], color = "black")
    axes[0].quiver(x_train[:, 0], x_train[:, 1], y_train[:, 0], y_train[:, 1], color = "grey", alpha = 0.8)
    axes[0].set_title("Ground Truth")
    axes[0].set_xlim(0, 1)
    axes[0].set_ylim(0, 1)
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    axes[0].set_aspect("equal")

    # --- Plot Prediction on the right ---
    axes[1].quiver(x_test[:, 0], x_test[:, 1], y_test_predictions[:, 0], y_test_predictions[:, 1], color = "blue")
    axes[1].set_title(f"{region_name.upper()} {model_name} Predictions for Run 1")
    axes[1].set_xlim(0, 1)
    axes[1].set_ylim(0, 1)
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    axes[1].set_aspect("equal")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Show all means

# %%
model_name = "dfNGP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

list_of_regions = ["region_lower_byrd"]

for region_name in list_of_regions:
    ### Training data ###
    # Step 1: define paths based on region_name
    path_to_training_tensor = subfolder_pre + "data/real_data/" + region_name + "_train_tensor.pt"
    path_to_test_tensor = subfolder_pre + "data/real_data/" + region_name + "_test_tensor.pt"

    # Step 2: load and tranpose to have rows as points
    train = torch.load(path_to_training_tensor, weights_only = False).T 
    test = torch.load(path_to_test_tensor, weights_only = False).T

    # Step 3: Extract data
    # train
    x_train = train[:, [0, 1]].detach().cpu()
    y_train = train[:, [3, 4]].detach().cpu()

    # test
    x_test = test[:, [0, 1]].detach().cpu()
    y_test = test[:, [3, 4]].detach().cpu()

    for run_num in range(6):
        run_num += 2
        print(run_num)

        ### Predictions ###
        path_predictions = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_test_mean_predictions_run_" + str(run_num) + ".pt"
        
        # NOTE: pt
        y_test_predictions = torch.load(path_predictions, weights_only = False).detach().cpu().numpy()

        fig, axes = plt.subplots(1, 2, figsize = (10, 5))

        # --- Plot Ground Truth on the left ---
        axes[0].quiver(x_test[:, 0], x_test[:, 1], y_test[:, 0], y_test[:, 1], color = "black")
        axes[0].quiver(x_train[:, 0], x_train[:, 1], y_train[:, 0], y_train[:, 1], color = "grey", alpha = 0.8)
        axes[0].set_title("Ground Truth")
        axes[0].set_xlim(0, 1)
        axes[0].set_ylim(0, 1)
        axes[0].set_xticks([])
        axes[0].set_yticks([])
        axes[0].set_aspect("equal")

        # --- Plot Prediction on the right ---
        axes[1].quiver(x_test[:, 0], x_test[:, 1], y_test_predictions[:, 0], y_test_predictions[:, 1], color = "blue")
        axes[1].set_title(f"{region_name.upper()} {model_name} Predictions for Run {run_num}")
        axes[1].set_xlim(0, 1)
        axes[1].set_ylim(0, 1)
        axes[1].set_xticks([])
        axes[1].set_yticks([])
        axes[1].set_aspect("equal")

        plt.tight_layout()
        plt.show()
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# # Mean module

# %%
from configs import N_SIDE_INFERENCE
SUB = 2

for region_name in list_of_regions:
    path_to_mean_module = "dfNGP_grid_inference" + "/" + region_name + "_" + model_name + "_grid_mean_module.pt"
    mean_module_grid = torch.load(path_to_mean_module, weights_only = False).detach().cpu().numpy()
    mean_module_grid_square = mean_module_grid.reshape(N_SIDE_INFERENCE, N_SIDE_INFERENCE, 2)

    grid_smaller = mean_module_grid_square[::SUB, ::SUB, :]
    # Create X, Y grid coordinates based on shape
    ny, nx = grid_smaller.shape[:2]
    x = np.arange(nx)
    y = np.arange(ny)
    X, Y = np.meshgrid(x, y)

    # Extract U, V components
    U = grid_smaller[:, :, 0]
    V = grid_smaller[:, :, 1]

    plt.figure(figsize = (6, 6))
    plt.quiver(X, Y, U, V)
    plt.gca().invert_yaxis()  # optional, if y-axis is flipped
    plt.axis('equal')
    plt.title(f"Quiver plot of subsampled vector field {region_name}")
    plt.show()

# %% [markdown]
# # PINN

# %% [markdown]
# ## PINN Loss convergence

# %%
model_name = "PINN"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    plt.figure(figsize = (8, 5))
    # Test loss will likely be >> Train loss so define first
    # NOTE: Plot combined loss too
    plt.plot(losses["Epoch"], losses["Test Loss RMSE"], label = "Test Loss RMSE", color = "red")
    plt.plot(losses["Epoch"], losses["Train Loss RMSE"], label = "Train Loss RMSE", color = "blue")

    plt.plot(losses["Epoch"], losses["Test Loss PINN"], label = "Train Loss mean(RMSE + div)", color = "pink", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["Train Loss PINN"], label = "Train Loss mean(RMSE + div)", color = "lightblue", alpha = 0.8)
    plt.xlabel("Epochs")
    plt.ylabel("RMSE Loss")
    plt.title(f"{region_name.upper()} {model_name} Training & Test Loss Over Epochs for Run 1")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## PINN predictions

# %%
model_name = "PINN"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    ### Training data ###
    # Step 1: define paths based on region_name
    path_to_training_tensor = subfolder_pre + "data/real_data/" + region_name + "_train_tensor.pt"
    path_to_test_tensor = subfolder_pre + "data/real_data/" + region_name + "_test_tensor.pt"

    # Step 2: load and tranpose to have rows as points
    train = torch.load(path_to_training_tensor, weights_only = False).T 
    test = torch.load(path_to_test_tensor, weights_only = False).T

    # Step 3: Extract data
    # train
    x_train = train[:, [0, 1]].detach().cpu()
    y_train = train[:, [3, 4]].detach().cpu()

    # test
    x_test = test[:, [0, 1]].detach().cpu()
    y_test = test[:, [3, 4]].detach().cpu()

    ### Predictions ###
    path_predictions = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_test_predictions.pt"
    # NOTE: pt
    y_test_predictions = torch.load(path_predictions, weights_only = False).detach().cpu().numpy()

    fig, axes = plt.subplots(1, 2, figsize = (10, 5))

    # --- Plot Ground Truth on the left ---
    axes[0].quiver(x_test[:, 0], x_test[:, 1], y_test[:, 0], y_test[:, 1], color = "black")
    axes[0].quiver(x_train[:, 0], x_train[:, 1], y_train[:, 0], y_train[:, 1], color = "grey", alpha = 0.8)
    axes[0].set_title("Ground Truth")
    axes[0].set_xlim(0, 1)
    axes[0].set_ylim(0, 1)
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    axes[0].set_aspect("equal")

    # --- Plot Prediction on the right ---
    axes[1].quiver(x_test[:, 0], x_test[:, 1], y_test_predictions[:, 0], y_test_predictions[:, 1], color = "blue")
    axes[1].set_title(f"{region_name.upper()} {model_name} Predictions for Run 1")
    axes[1].set_xlim(0, 1)
    axes[1].set_ylim(0, 1)
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    axes[1].set_aspect("equal")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # dfGP

# %% [markdown]
# ## dfGP Loss convergence

# %%
model_name = "dfGP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    fig, ax1 = plt.subplots(figsize = (8, 5))

    # Primary y-axis: RMSE
    ax1.plot(losses["Epoch"], losses["Test RMSE"], label = "Test RMSE", color="red")
    ax1.plot(losses["Epoch"], losses["Train RMSE"], label = "Train RMSE", color="blue")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("RMSE Loss")
    ax1.tick_params(axis = 'y', labelcolor = "black")

    # Secondary y-axis: NLML
    ax2 = ax1.twinx()
    ax2.plot(losses["Epoch"], losses["Train NLML"], label = "Train NLML", color = "green", linestyle = "--")
    ax2.set_ylabel("Negative Log Marginal Likelihood (NLML) - objective", color = "green")
    ax2.tick_params(axis = 'y', labelcolor = "green")

    # Combine legends
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc = "upper right")

    plt.title(f"{region_name.upper()} {model_name} Training & Test Loss Over Epochs for Run 1")
    ax1.grid()
    plt.tight_layout()

    plt.show()

# %% [markdown]
# ## dfGP Hyperparameter evolution

# %%
model_name = "dfGP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    plt.figure(figsize = (8, 5))
    plt.plot(losses["Epoch"], losses["l1"], label = "l1", color = "peru", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["l2"], label = "l2", color = "sienna", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["outputscale_var"], label = "Outputscale var.", color = "teal")
    plt.plot(losses["Epoch"], losses["noise_var"], label = "Noise var.", color = "red")

    plt.xlabel("Epochs")
    plt.ylabel("dfGP hyperparameters")
    plt.title(f"{region_name.upper()} {model_name} Hyperparameter convergence for Run 1")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## dfGP Predictions

# %%
model_name = "dfGP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    ### Training data ###
    # Step 1: define paths based on region_name
    path_to_training_tensor = subfolder_pre + "data/real_data/" + region_name + "_train_tensor.pt"
    path_to_test_tensor = subfolder_pre + "data/real_data/" + region_name + "_test_tensor.pt"

    # Step 2: load and tranpose to have rows as points
    train = torch.load(path_to_training_tensor, weights_only = False).T 
    test = torch.load(path_to_test_tensor, weights_only = False).T

    # Step 3: Extract data
    # train
    x_train = train[:, [0, 1]].detach().cpu()
    y_train = train[:, [3, 4]].detach().cpu()

    # test
    x_test = test[:, [0, 1]].detach().cpu()
    y_test = test[:, [3, 4]].detach().cpu()

    ### Predictions ###
    path_predictions = MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_test_mean_predictions.pt"
    # NOTE: pt
    y_test_predictions = torch.load(subfolder_pre + path_predictions, weights_only = False).detach().cpu().numpy()

    fig, axes = plt.subplots(1, 2, figsize = (10, 5))

    # --- Plot Ground Truth on the left ---
    axes[0].quiver(x_test[:, 0], x_test[:, 1], y_test[:, 0], y_test[:, 1], color = "black")
    axes[0].quiver(x_train[:, 0], x_train[:, 1], y_train[:, 0], y_train[:, 1], color = "grey", alpha = 0.8)
    axes[0].set_title("Ground Truth")
    axes[0].set_xlim(0, 1)
    axes[0].set_ylim(0, 1)
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    axes[0].set_aspect("equal")

    # --- Plot Prediction on the right ---
    axes[1].quiver(x_test[:, 0], x_test[:, 1], y_test_predictions[:, 0], y_test_predictions[:, 1], color = "blue")
    axes[1].set_title(f"{region_name.upper()} {model_name} Predictions for Run 1")
    axes[1].set_xlim(0, 1)
    axes[1].set_ylim(0, 1)
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    axes[1].set_aspect("equal")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # dfGPcm
#
# ## dfGPcm Loss convergence

# %%
import configs
model_name = "dfGPcm"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    fig, ax1 = plt.subplots(figsize = (8, 5))

    # Primary y-axis: RMSE
    ax1.plot(losses["Epoch"], losses["Test RMSE"], label = "Test RMSE", color = "red")
    ax1.plot(losses["Epoch"], losses["Train RMSE"], label = "Train RMSE", color = "blue")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("RMSE Loss")
    ax1.tick_params(axis = 'y', labelcolor = "black")

    # Secondary y-axis: NLML
    ax2 = ax1.twinx()
    ax2.plot(losses["Epoch"], losses["Train NLML"], label = "Train NLML", color = "green", linestyle = "--")
    ax2.set_ylabel("Negative Log Marginal Likelihood (NLML) - objective", color = "green")
    ax2.tick_params(axis = 'y', labelcolor = "green")

    # Combine legends
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc = "upper right")

    plt.title(f"{region_name.upper()} {model_name} Training & Test Loss Over Epochs for Run 1")
    ax1.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## dfGPcm Hyperparameter evolution

# %%
model_name = "dfGPcm"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    plt.figure(figsize = (8, 5))
    plt.plot(losses["Epoch"], losses["l1"], label = "l1", color = "peru", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["l2"], label = "l2", color = "sienna", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["outputscale_var"], label = "Outputscale var.", color = "teal")
    plt.plot(losses["Epoch"], losses["noise_var"], label = "Noise var.", color = "red")

    plt.xlabel("Epochs")
    plt.ylabel("dfGP hyperparameters")
    plt.title(f"{region_name.upper()} {model_name} Hyperparameter convergence for Run 1")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## dfGPcm Predictions

# %%
model_name = "dfGPcm"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    ### Training data ###
    # Step 1: define paths based on region_name
    path_to_training_tensor = subfolder_pre + "data/real_data/" + region_name + "_train_tensor.pt"
    path_to_test_tensor = subfolder_pre + "data/real_data/" + region_name + "_test_tensor.pt"

    # Step 2: load and tranpose to have rows as points
    train = torch.load(path_to_training_tensor, weights_only = False).T 
    test = torch.load(path_to_test_tensor, weights_only = False).T

    # Step 3: Extract data
    # train
    x_train = train[:, [0, 1]].detach().cpu()
    y_train = train[:, [3, 4]].detach().cpu()

    # test
    x_test = test[:, [0, 1]].detach().cpu()
    y_test = test[:, [3, 4]].detach().cpu()

    ### Predictions ###
    path_predictions = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_test_mean_predictions.pt"
    # NOTE: pt
    y_test_predictions = torch.load(path_predictions, weights_only = False).detach().cpu().numpy()

    fig, axes = plt.subplots(1, 2, figsize = (10, 5))

    # --- Plot Ground Truth on the left ---
    axes[0].quiver(x_test[:, 0], x_test[:, 1], y_test[:, 0], y_test[:, 1], color = "black")
    axes[0].quiver(x_train[:, 0], x_train[:, 1], y_train[:, 0], y_train[:, 1], color = "grey", alpha = 0.8)
    axes[0].set_title("Ground Truth")
    axes[0].set_xlim(0, 1)
    axes[0].set_ylim(0, 1)
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    axes[0].set_aspect("equal")

    # --- Plot Prediction on the right ---
    axes[1].quiver(x_test[:, 0], x_test[:, 1], y_test_predictions[:, 0], y_test_predictions[:, 1], color = "blue")
    axes[1].set_title(f"{region_name.upper()} {model_name} Predictions for Run 1")
    axes[1].set_xlim(0, 1)
    axes[1].set_ylim(0, 1)
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    axes[1].set_aspect("equal")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # GP

# %% [markdown]
# ## GP Loss convergence

# %%
model_name = "GP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    fig, ax1 = plt.subplots(figsize = (8, 5))

    # Primary y-axis: RMSE
    ax1.plot(losses["Epoch"], losses["Test RMSE"], label = "Test RMSE", color = "red")
    ax1.plot(losses["Epoch"], losses["Train RMSE"], label="Train Loss RMSE", color = "blue")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("RMSE Loss")
    ax1.tick_params(axis = 'y', labelcolor = "black")

    # Secondary y-axis: NLML
    ax2 = ax1.twinx()
    ax2.plot(losses["Epoch"], losses["Train NLML"], label = "Train NLML", color = "green", linestyle = "--")
    ax2.set_ylabel("Negative Log Marginal Likelihood (NLML) - objective", color = "green")
    ax2.tick_params(axis = 'y', labelcolor = "green")

    # Combine legends
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc = "upper right")

    plt.title(f"{region_name.upper()} {model_name} Training & Test Loss Over Epochs for Run 1")
    ax1.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GP Hyperparameter evolution

# %%
model_name = "GP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    plt.figure(figsize = (8, 5))
 
    plt.plot(losses["Epoch"], losses["l1"], label = "l1", color = "peru", alpha = 0.8)
    plt.plot(losses["Epoch"], losses["l2"], label = "l2", color = "sienna", alpha = 0.8)

    plt.plot(losses["Epoch"], losses["Buu"], label = "Buu", color = "teal", linestyle = "--")
    plt.plot(losses["Epoch"], losses["Bvv"], label = "Bvv", color = "green", linestyle = "--")
    plt.plot(losses["Epoch"], losses["Buv"], label = "Buv", color = "cornflowerblue", linestyle = "--")
    plt.plot(losses["Epoch"], losses["Bvu"], label = "Bvu", color = "dodgerblue", linestyle = "--")

    plt.plot(losses["Epoch"], losses["noise_var"], label = "Noise var.", color = "steelblue")

    plt.xlabel("Epochs")
    plt.ylabel("GP hyperparameters")
    plt.title(f"{region_name.upper()} {model_name} Hyperparameter convergence for Run 1")
    plt.legend()
    plt.grid()

# %% [markdown]
# ## GP predictions

# %%
model_name = "GP"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    ### Training data ###
    # Step 1: define paths based on region_name
    path_to_training_tensor = subfolder_pre + "data/real_data/" + region_name + "_train_tensor.pt"
    path_to_test_tensor = subfolder_pre + "data/real_data/" + region_name + "_test_tensor.pt"

    # Step 2: load and tranpose to have rows as points
    train = torch.load(path_to_training_tensor, weights_only = False).T 
    test = torch.load(path_to_test_tensor, weights_only = False).T

    # Step 3: Extract data
    # train
    x_train = train[:, [0, 1]].detach().cpu()
    y_train = train[:, [3, 4]].detach().cpu()

    # test
    x_test = test[:, [0, 1]].detach().cpu()
    y_test = test[:, [3, 4]].detach().cpu()

    ### Predictions ###
    path_predictions = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_test_mean_predictions.pt"
    # NOTE: pt
    y_test_predictions = torch.load(path_predictions, weights_only = False).detach().cpu().numpy()

    fig, axes = plt.subplots(1, 2, figsize = (10, 5))

    # --- Plot Ground Truth on the left ---
    axes[0].quiver(x_test[:, 0], x_test[:, 1], y_test[:, 0], y_test[:, 1], color = "black")
    axes[0].quiver(x_train[:, 0], x_train[:, 1], y_train[:, 0], y_train[:, 1], color = "grey", alpha = 0.8)
    axes[0].set_title("Ground Truth")
    axes[0].set_xlim(0, 1)
    axes[0].set_ylim(0, 1)
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    axes[0].set_aspect("equal")

    # --- Plot Prediction on the right ---
    axes[1].quiver(x_test[:, 0], x_test[:, 1], y_test_predictions[:, 0], y_test_predictions[:, 1], color = "blue")
    axes[1].set_title(f"{region_name.upper()} {model_name} Predictions for Run 1")
    axes[1].set_xlim(0, 1)
    axes[1].set_ylim(0, 1)
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    axes[1].set_aspect("equal")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # dfNN

# %% [markdown]
# ## dfNN Loss convergence

# %%
model_name = "dfNN"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    path_losses_over_epochs = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_losses_over_epochs.csv"
    losses = pd.read_csv(path_losses_over_epochs)

    plt.figure(figsize = (8, 5))
    # Test loss will likely be >> Train loss so define first
    # NOTE: Plot combined loss too
    plt.plot(losses["Epoch"], losses["Test Loss RMSE"], label = "Test Loss RMSE", color = "red")
    plt.plot(losses["Epoch"], losses["Train Loss RMSE"], label = "Train Loss RMSE", color = "blue")
    plt.xlabel("Epochs")
    plt.ylabel("RMSE Loss")
    plt.title(f"{region_name.upper()} {model_name} Training & Test Loss Over Epochs for Run 1")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## dfNN Hyperparameter evolution

# %% [markdown]
# ## dfNN predictions

# %%
model_name = "dfNN"
MODEL_REAL_RESULTS_DIR = getattr(configs, f"{model_name}_REAL_RESULTS_DIR")

for region_name in list_of_regions:
    ### Training data ###
    # Step 1: define paths based on region_name
    path_to_training_tensor = subfolder_pre + "data/real_data/" + region_name + "_train_tensor.pt"
    path_to_test_tensor = subfolder_pre + "data/real_data/" + region_name + "_test_tensor.pt"

    # Step 2: load and tranpose to have rows as points
    train = torch.load(path_to_training_tensor, weights_only = False).T 
    test = torch.load(path_to_test_tensor, weights_only = False).T

    # Step 3: Extract data
    # train
    x_train = train[:, [0, 1]].detach().cpu()
    y_train = train[:, [3, 4]].detach().cpu()

    # test
    x_test = test[:, [0, 1]].detach().cpu()
    y_test = test[:, [3, 4]].detach().cpu()

    ### Predictions ###
    path_predictions = subfolder_pre + MODEL_REAL_RESULTS_DIR + "/" + region_name + "_" + model_name + "_test_predictions.pt"
    # NOTE: pt
    y_test_predictions = torch.load(path_predictions, weights_only = False).detach().cpu().numpy()

    fig, axes = plt.subplots(1, 2, figsize = (10, 5))

    # --- Plot Ground Truth on the left ---
    axes[0].quiver(x_test[:, 0], x_test[:, 1], y_test[:, 0], y_test[:, 1], color = "black")
    axes[0].quiver(x_train[:, 0], x_train[:, 1], y_train[:, 0], y_train[:, 1], color = "grey", alpha = 0.8)
    axes[0].set_title("Ground Truth")
    axes[0].set_xlim(0, 1)
    axes[0].set_ylim(0, 1)
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    axes[0].set_aspect("equal")

    # --- Plot Prediction on the right ---
    axes[1].quiver(x_test[:, 0], x_test[:, 1], y_test_predictions[:, 0], y_test_predictions[:, 1], color = "blue")
    axes[1].set_title(f"{region_name.upper()} {model_name} Predictions for Run 1")
    axes[1].set_xlim(0, 1)
    axes[1].set_ylim(0, 1)
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    axes[1].set_aspect("equal")

    plt.tight_layout()
    plt.show()
